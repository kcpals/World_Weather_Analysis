# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
# Import API key
from config import weather_api_key
from config import g_key

# %%
# Create a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-88.81610858435495, 148.31883279351825), (30.02340780584892, 64.18566103971747), (75.90645777857733, -73.74687287231562), (22.892990985791315, -164.76283243534715), (56.968532060529384, -167.43974327572414), (-28.340513950997988, 29.00251955401373), (-57.55385782660233, 102.60946487111534), (-13.588182980358468, 94.7861090898054), (-54.96848713507917, 65.84427333552227), (-10.606324195105216, 41.171241682992644), (84.83143328393174, 25.755854077106136), (-27.130946383155056, -15.204498228489939), (35.675753211422176, 169.73957942155346), (13.404391029220847, 87.14853289727426), (-9.90874155964869, -68.54206760222701), (-52.22434590365708, 112.20387344888957), (44.13163692223981, -65.89302168293811), (56.538197015940995, 102.36759509119793), (65.44471243078769, 39.51531941967963), (36.530006049422155, 74.52431906033121), (28.64035198175918, -18.090172419090266), (-44.12045451021895, 156.60189398950382), (65.58007793136488, -101.24511102630105), (22.656591485637946, 90.00155884940182), (76.02814799319498, -22.098867945697066), (8.506627560836748, 90.95316428475678), (-15.267578917040524, -18.18008569382752), (-54.47103414237377, 97.8757951758896), (-10.101652209503527, 130.04323354086347), (89.9808967403344, 165.37348234986484), (-14.964707654700504, 165.19905601289446), (57.558850684925346, -163.89172996748616), (19.642496334834092, 152.70065365010913), (89.8185103671278, 106.42607497389952), (17.599692507594156, -79.32374349716827), (83.51001261204834, 32.68454476393123), (58.92510481274101, 48.165779130781374), (44.936761456375024, -160.47121672254542), (25.615011865914198, 120.94435550309112), (-88.36882752561327, 144.4463318488232), (-68.30739427451888, -62.299902501486926), (-80.52778605400422, -120.34446913118549), (-45.10042168277881, 174.58496646555346), (-38.40226961584771, -156.51947158309457), (-12.136833430361719, 17.90282537082635), (82.36564421729716, 7.343572642376131), (61.42313829846097, -28.855478781679636), (-61.65956073436023, 0.9538852722824913), (-42.54455437528847, -149.60777584764378), (-46.09257721804394, 95.8325262273558), (-7.768080981506671, 17.807299198591323), (-79.92510245897819, 95.04934251593716), (-25.541038231745105, 129.69917420803546), (22.940895473270047, -24.82300454250813), (-12.54807384867432, -169.60561820886275), (78.70840582259166, -172.95747445740227), (-86.0913553724899, 37.3075360528284), (-55.90281544025108, -148.50375872558206), (-27.3759258941608, 12.864648066236981), (80.98593958535184, -89.45753215976794), (76.36762958348487, 74.58010279844956), (19.582070440302658, -111.95911584381264), (86.91425529595077, 83.34033469806957), (-29.504245105540882, -19.790218586382736), (44.832425206907686, 161.553496412622), (42.42560009322585, 103.18237548492203), (-27.76443736385179, 175.2220618413087), (68.16690691977709, -163.32683413472), (-9.904290370336057, 36.94160596673083), (14.297374412767553, -162.89666208646278), (-46.31716635018668, -61.562621288991565), (11.664111198724967, 81.27067059831262), (30.27846835062232, -139.3196903781042), (44.02150270691064, 155.80210885855274), (88.01114469135246, -132.66867540663796), (20.490989635109457, -73.0281617055604), (72.95908413471872, -96.27418704486085), (-77.62576933398294, -167.93316480406617), (-15.004555555930452, -84.97757251955643), (-47.233047145027165, 5.153138903106935), (-16.815797641799293, -91.14051339763333), (11.697709212754575, 178.01419385232612), (15.125985038233551, 28.58574548266205), (59.46776123593699, 48.10511178400921), (-86.75917180116723, 51.4840112062092), (12.311575697520354, 7.468575257184256), (-57.687329441445584, 161.62797783973264), (-15.140871249613284, -92.86115529967708), (87.59090676320008, -149.15162034207017), (59.99780680258493, -100.58049672952748), (12.548822135842798, 56.86715058411886), (-63.53806525070576, -21.10281255600924), (-11.569333659603316, -116.76785871241083), (-20.11538200935827, -86.29995994285163), (27.943279178243074, 126.08705824243509), (-82.40416780478135, -95.62893688306079 ...

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | dalbandin
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | harrismith
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | madimba
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | yarada
# Processing Record 15 of Set 1 | xapuri
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | yarmouth
# Processing Record 18 of Set 1 | vidim
# Processing Record 19 of Set 1 | severodvinsk
# Processing Record 20 of Set 1 | hunza
# 'coord'
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | pirojpur
# Processing Record 24 of Set 1 | illoqqortoormiut
# 'coord'
# Processing Record 25 of Set 1 | port blair
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | nguiu
# 'coord'
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | luganville
# Processing Record 30 of Set 1 | katsuura
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | lucea
# Processing Record 33 of Set 1 | berlevag
# Processing Record 34 of Set 1 | darovskoy
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | tanshui
# 'coord'
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | christchurch
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | camacupa
# Processing Record 42 of Set 1 | barentsburg
# 'coord'
# Processing Record 43 of Set 1 | olafsvik
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | kasongo-lunda
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | samusu
# 'coord'
# Processing Record 49 of Set 1 | mys shmidta
# 'coord'
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | hovd
# Processing Record 6 of Set 2 | kaeo
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | liwale
# Processing Record 9 of Set 2 | nanakuli
# Processing Record 10 of Set 2 | rawson
# Processing Record 11 of Set 2 | marakkanam
# Processing Record 12 of Set 2 | fortuna
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | port-de-paix
# 'coord'
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | hualmay
# Processing Record 17 of Set 2 | huarmey
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | bara
# Processing Record 20 of Set 2 | maromitsa
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | malumfashi
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | san cristobal
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | pisco
# Processing Record 30 of Set 2 | yomitan
# 'coord'
# Processing Record 31 of Set 2 | belushya guba
# 'coord'
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | armacao de pera
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | banjar
# Processing Record 37 of Set 2 | betare oya
# Processing Record 38 of Set 2 | grindavik
# Processing Record 39 of Set 2 | jiaonan
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | nhulunbuy
# Processing Record 42 of Set 2 | marsh harbour
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | kutum
# Processing Record 45 of Set 2 | culebra
# Processing Record 46 of Set 2 | warqla
# 'coord'
# Processing Record 47 of Set 2 | santa maria
# Processing Record 48 of Set 2 | dauphin
# Processing Record 49 of Set 2 | vaitupu
# 'coord'
# Processing Record 50 of Set 2 | san carlos de bariloche
# Processing Record 1 of Set 3 | vanimo
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | lalomanu
# 'coord'
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | emerald
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | olds
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | mayumba
# Processing Record 13 of Set 3 | raudeberg
# Processing Record 14 of Set 3 | magan
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | tsihombe
# 'coord'
# Processing Record 17 of Set 3 | santa cruz
# Processing Record 18 of Set 3 | shizunai
# Processing Record 19 of Set 3 | kiunga
# Processing Record 20 of Set 3 | am timan
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | bac lieu
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | seondha
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | baoqing
# Processing Record 29 of Set 3 | rafiganj
# Processing Record 30 of Set 3 | saryshagan
# 'coord'
# Processing Record 31 of Set 3 | isangel
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | santa rita
# Processing Record 34 of Set 3 | little current
# Processing Record 35 of Set 3 | oytal
# Processing Record 36 of Set 3 | goya
# Processing Record 37 of Set 3 | thai nguyen
# Processing Record 38 of Set 3 | makung
# 'coord'
# Processing Record 39 of Set 3 | tornio
# Processing Record 40 of Set 3 | bereslavka
# Processing Record 41 of Set 3 | taga
# Processing Record 42 of Set 3 | srednekolymsk
# Processing Record 43 of Set 3 | merced
# Processing Record 44 of Set 3 | amderma
# 'coord'
# Processing Record 45 of Set 3 | likhoslavl
# Processing Record 46 of Set 3 | lagoa
# Processing Record 47 of Set 3 | vao
# Processing Record 48 of Set 3 | lucapa
# Processing Record 49 of Set 3 | comarapa
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | bad aussee
# Processing Record 3 of Set 4 | wulanhaote
# 'coord'
# Processing Record 4 of Set 4 | lakes entrance
# Processing Record 5 of Set 4 | kormilovka
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | osa
# Processing Record 8 of Set 4 | saskylakh
# Processing Record 9 of Set 4 | shenjiamen
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | sitangkai
# Processing Record 12 of Set 4 | ozernovskiy
# Processing Record 13 of Set 4 | castro
# Processing Record 14 of Set 4 | victoria
# Processing Record 15 of Set 4 | kiama
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | vila do maio
# Processing Record 19 of Set 4 | naron
# Processing Record 20 of Set 4 | oranjestad
# Processing Record 21 of Set 4 | buchanan
# Processing Record 22 of Set 4 | andenes
# Processing Record 23 of Set 4 | avera
# Processing Record 24 of Set 4 | marcona
# 'coord'
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | lavrentiya
# Processing Record 27 of Set 4 | kenai
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | bredasdorp
# Processing Record 30 of Set 4 | rocha
# Processing Record 31 of Set 4 | svobodnyy
# Processing Record 32 of Set 4 | clyde
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | borlange
# 'coord'
# Processing Record 35 of Set 4 | saint-georges
# Processing Record 36 of Set 4 | auki
# Processing Record 37 of Set 4 | dinsor
# 'coord'
# Processing Record 38 of Set 4 | vila velha
# Processing Record 39 of Set 4 | beisfjord
# Processing Record 40 of Set 4 | lubao
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | homer
# Processing Record 43 of Set 4 | pangnirtung
# Processing Record 44 of Set 4 | namatanai
# Processing Record 45 of Set 4 | ponta delgada
# Processing Record 46 of Set 4 | biaora
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | oyem
# Processing Record 49 of Set 4 | zalesovo
# Processing Record 50 of Set 4 | souillac
# Processing Record 1 of Set 5 | weligama
# Processing Record 2 of Set 5 | uspenskaya
# Processing Record 3 of Set 5 | nyaunglebin
# Processing Record 4 of Set 5 | attawapiskat
# 'coord'
# Processing Record 5 of Set 5 | pulsano
# Processing Record 6 of Set 5 | ballina
# Processing Record 7 of Set 5 | bolungarvik
# 'coord'
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | poum
# Processing Record 10 of Set 5 | ust-kut
# Processing Record 11 of Set 5 | rafraf
# Processing Record 12 of Set 5 | terenos
# Processing Record 13 of Set 5 | prince rupert
# Processing Record 14 of Set 5 | adrar
# Processing Record 15 of Set 5 | chapais
# Processing Record 16 of Set 5 | gilgit
# Processing Record 17 of Set 5 | sosnovo-ozerskoye
# Processing Record 18 of Set 5 | furmanov
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | balimo
# 'coord'
# Processing Record 21 of Set 5 | cabedelo
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | chokurdakh
# Processing Record 24 of Set 5 | muzambinho
# Processing Record 25 of Set 5 | yatou
# Processing Record 26 of Set 5 | abha
# Processing Record 27 of Set 5 | mergui
# 'coord'
# Processing Record 28 of Set 5 | bestobe
# Processing Record 29 of Set 5 | pokrovsk
# Processing Record 30 of Set 5 | xuanwu
# Processing Record 31 of Set 5 | hammerfest
# Processing Record 32 of Set 5 | torbay
# Processing Record 33 of Set 5 | havoysund
# Processing Record 34 of Set 5 | iztapa
# Processing Record 35 of Set 5 | labutta
# 'coord'
# Processing Record 36 of Set 5 | gernsbach
# Processing Record 37 of Set 5 | jahrom
# 'coord'
# Processing Record 38 of Set 5 | saint-francois
# Processing Record 39 of Set 5 | polis
# Processing Record 40 of Set 5 | panjab
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | muros
# Processing Record 43 of Set 5 | sparbu
# Processing Record 44 of Set 5 | frontera
# Processing Record 45 of Set 5 | caravelas
# Processing Record 46 of Set 5 | komoro
# Processing Record 47 of Set 5 | nizhneyansk
# 'coord'
# Processing Record 48 of Set 5 | tumannyy
# 'coord'
# Processing Record 49 of Set 5 | acapulco
# Processing Record 50 of Set 5 | tanjong tokong
# 'coord'
# Processing Record 1 of Set 6 | old saybrook
# Processing Record 2 of Set 6 | kolpashevo
# Processing Record 3 of Set 6 | yerbogachen
# Processing Record 4 of Set 6 | kegayli
# 'coord'
# Processing Record 5 of Set 6 | yangjiang
# Processing Record 6 of Set 6 | usinsk
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | taolanaro
# 'coord'
# Processing Record 9 of Set 6 | wagga wagga
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | ous
# Processing Record 12 of Set 6 | puerto cabezas
# Processing Record 13 of Set 6 | chaykovskaya
# Processing Record 14 of Set 6 | bonthe
# Processing Record 15 of Set 6 | siniscola
# Processing Record 16 of Set 6 | armizonskoye
# Processing Record 17 of Set 6 | sambava
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | college
# Processing Record 21 of Set 6 | grand river south east
# 'coord'
# Processing Record 22 of Set 6 | tura
# Processing Record 23 of Set 6 | paso de los toros
# Processing Record 24 of Set 6 | sentyabrskiy
# 'coord'
# Processing Record 25 of Set 6 | skibbereen
# Processing Record 26 of Set 6 | north myrtle beach
# Processing Record 27 of Set 6 | sompeta
# Processing Record 28 of Set 6 | gbarnga
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | gizo
# Processing Record 31 of Set 6 | zheleznodorozhnyy
# Processing Record 32 of Set 6 | mackay
# Processing Record 33 of Set 6 | hobyo
# Processing Record 34 of Set 6 | port hardy
# Processing Record 35 of Set 6 | doha
# Processing Record 36 of Set 6 | altay
# Processing Record 37 of Set 6 | sokoni
# Processing Record 38 of Set 6 | chernyshkovskiy
# Processing Record 39 of Set 6 | upernavik
# Processing Record 40 of Set 6 | ahipara
# Processing Record 41 of Set 6 | sorong
# Processing Record 42 of Set 6 | aklavik
# Processing Record 43 of Set 6 | manggar
# Processing Record 44 of Set 6 | kaseda
# Processing Record 45 of Set 6 | rosarito
# Processing Record 46 of Set 6 | nanortalik
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | kilindoni
# Processing Record 49 of Set 6 | rabat
# Processing Record 50 of Set 6 | honningsvag
# Processing Record 1 of Set 7 | tabialan
# 'coord'
# Processing Record 2 of Set 7 | katha
# 'coord'
# Processing Record 3 of Set 7 | brumunddal
# Processing Record 4 of Set 7 | bykovo
# Processing Record 5 of Set 7 | omsukchan
# Processing Record 6 of Set 7 | port augusta
# Processing Record 7 of Set 7 | watsa
# Processing Record 8 of Set 7 | litoral del san juan
# 'coord'
# Processing Record 9 of Set 7 | marawi
# Processing Record 10 of Set 7 | chor
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | broome
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | rio grande
# Processing Record 15 of Set 7 | safaga
# Processing Record 16 of Set 7 | plerin
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | longlac
# 'coord'
# Processing Record 19 of Set 7 | mehamn
# Processing Record 20 of Set 7 | carballo
# Processing Record 21 of Set 7 | nur
# Processing Record 22 of Set 7 | flinders
# Processing Record 23 of Set 7 | muroto
# Processing Record 24 of Set 7 | tiruchchirappalli
# Processing Record 25 of Set 7 | cherskiy
# Processing Record 26 of Set 7 | el triunfo
# Processing Record 27 of Set 7 | creel
# Processing Record 28 of Set 7 | san luis
# Processing Record 29 of Set 7 | santa rosalia
# Processing Record 30 of Set 7 | nexo
# Processing Record 31 of Set 7 | haines junction
# Processing Record 32 of Set 7 | erzin
# Processing Record 33 of Set 7 | tilichiki
# Processing Record 34 of Set 7 | kaitangata
# Processing Record 35 of Set 7 | mount vernon
# Processing Record 36 of Set 7 | severo-yeniseyskiy
# Processing Record 37 of Set 7 | syedove
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | dawlatabad
# Processing Record 40 of Set 7 | clyde river
# Processing Record 41 of Set 7 | asfi
# Processing Record 42 of Set 7 | bandarbeyla
# Processing Record 43 of Set 7 | petropavlovka
# Processing Record 44 of Set 7 | aquiraz
# Processing Record 45 of Set 7 | lekoni
# Processing Record 46 of Set 7 | coxim
# Processing Record 47 of Set 7 | kosh-agach
# Processing Record 48 of Set 7 | narsaq
# Processing Record 49 of Set 7 | deniliquin
# Processing Record 50 of Set 7 | batemans bay
# Processing Record 1 of Set 8 | ostersund
# Processing Record 2 of Set 8 | saleaula
# 'coord'
# Processing Record 3 of Set 8 | cap malheureux
# Processing Record 4 of Set 8 | meiganga
# Processing Record 5 of Set 8 | kalabo
# Processing Record 6 of Set 8 | gigmoto
# Processing Record 7 of Set 8 | laguna
# Processing Record 8 of Set 8 | sawakin
# Processing Record 9 of Set 8 | denpasar
# Processing Record 10 of Set 8 | rosario oeste
# Processing Record 11 of Set 8 | skalistyy
# 'coord'
# Processing Record 12 of Set 8 | sistranda
# Processing Record 13 of Set 8 | aripuana
# Processing Record 14 of Set 8 | nazas
# Processing Record 15 of Set 8 | ambalavao
# Processing Record 16 of Set 8 | palmer
# Processing Record 17 of Set 8 | muzhi
# Processing Record 18 of Set 8 | verkhnyaya inta
# Processing Record 19 of Set 8 | arraial do cabo
# Processing Record 20 of Set 8 | korla
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | schwarzenbek
# Processing Record 23 of Set 8 | araouane
# Processing Record 24 of Set 8 | trincomalee
# Processing Record 25 of Set 8 | kuala terengganu
# Processing Record 26 of Set 8 | tabou
# Processing Record 27 of Set 8 | vaitape
# Processing Record 28 of Set 8 | bubaque
# Processing Record 29 of Set 8 | mecca
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | biryusinsk
# Processing Record 32 of Set 8 | rawannawi
# 'coord'
# Processing Record 33 of Set 8 | egvekinot
# Processing Record 34 of Set 8 | yar-sale
# Processing Record 35 of Set 8 | jalu
# Processing Record 36 of Set 8 | shahreza
# Processing Record 37 of Set 8 | tigil
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | burns lake
# Processing Record 40 of Set 8 | rio gallegos
# Processing Record 41 of Set 8 | baghdad
# Processing Record 42 of Set 8 | solnechnyy
# Processing Record 43 of Set 8 | kologriv
# Processing Record 44 of Set 8 | yumen
# Processing Record 45 of Set 8 | westport
# Processing Record 46 of Set 8 | vostok
# Processing Record 47 of Set 8 | birnin kebbi
# Processing Record 48 of Set 8 | sola
# Processing Record 49 of Set 8 | mbandaka
# Processing Record 50 of Set 8 | touros
# Processing Record 1 of Set 9 | caidian
# Processing Record 2 of Set 9 | dali
# Processing Record 3 of Set 9 | san carlos
# Processing Record 4 of Set 9 | kingsville
# Processing Record 5 of Set 9 | hofn
# Processing Record 6 of Set 9 | hobe sound
# Processing Record 7 of Set 9 | praia da vitoria
# Processing Record 8 of Set 9 | jasper
# Processing Record 9 of Set 9 | tosham
# Processing Record 10 of Set 9 | mindelo
# Processing Record 11 of Set 9 | plavinas
# Processing Record 12 of Set 9 | karauzyak
# 'coord'
# Processing Record 13 of Set 9 | maltahohe
# Processing Record 14 of Set 9 | sitka
# Processing Record 15 of Set 9 | leningradskiy
# Processing Record 16 of Set 9 | sao joao da barra
# Processing Record 17 of Set 9 | sechura
# Processing Record 18 of Set 9 | toora-khem
# Processing Record 19 of Set 9 | warrington
# Processing Record 20 of Set 9 | sao jose da coroa grande
# Processing Record 21 of Set 9 | ilebo
# Processing Record 22 of Set 9 | yako
# Processing Record 23 of Set 9 | paamiut
# Processing Record 24 of Set 9 | katherine
# Processing Record 25 of Set 9 | namibe
# Processing Record 26 of Set 9 | hirara
# Processing Record 27 of Set 9 | viedma
# Processing Record 28 of Set 9 | tual
# Processing Record 29 of Set 9 | bambanglipuro
# Processing Record 30 of Set 9 | marfino
# Processing Record 31 of Set 9 | chyhyryn
# Processing Record 32 of Set 9 | quesnel
# Processing Record 33 of Set 9 | ino
# Processing Record 34 of Set 9 | henties bay
# Processing Record 35 of Set 9 | tarnogskiy gorodok
# Processing Record 36 of Set 9 | ondorhaan
# 'coord'
# Processing Record 37 of Set 9 | puksoozero
# Processing Record 38 of Set 9 | faya
# Processing Record 39 of Set 9 | deer lake
# Processing Record 40 of Set 9 | astara
# Processing Record 41 of Set 9 | alofi
# Processing Record 42 of Set 9 | goderich
# Processing Record 43 of Set 9 | shache
# Processing Record 44 of Set 9 | axim
# Processing Record 45 of Set 9 | ancud
# Processing Record 46 of Set 9 | san patricio
# Processing Record 47 of Set 9 | santa fe
# Processing Record 48 of Set 9 | pilot butte
# Processing Record 49 of Set 9 | port moresby
# Processing Record 50 of Set 9 | siavonga
# Processing Record 1 of Set 10 | radcliff
# Processing Record 2 of Set 10 | gondal
# Processing Record 3 of Set 10 | przhevalskoye
# Processing Record 4 of Set 10 | dawei
# Processing Record 5 of Set 10 | basqal
# Processing Record 6 of Set 10 | fort nelson
# Processing Record 7 of Set 10 | pringsewu
# Processing Record 8 of Set 10 | gvarv
# Processing Record 9 of Set 10 | flin flon
# Processing Record 10 of Set 10 | potosi
# Processing Record 11 of Set 10 | kapit
# Processing Record 12 of Set 10 | kahului
# Processing Record 13 of Set 10 | kupang
# Processing Record 14 of Set 10 | goundam
# Processing Record 15 of Set 10 | batagay
# Processing Record 16 of Set 10 | fensmark
# Processing Record 17 of Set 10 | bilma
# Processing Record 18 of Set 10 | aswan
# Processing Record 19 of Set 10 | caconda
# Processing Record 20 of Set 10 | bonavista
# Processing Record 21 of Set 10 | moranbah
# Processing Record 22 of Set 10 | guerrero negro
# Processing Record 23 of Set 10 | verkhoyansk
# Processing Record 24 of Set 10 | provideniya
# Processing Record 25 of Set 10 | majene
# Processing Record 26 of Set 10 | palembang
# Processing Record 27 of Set 10 | howard springs
# Processing Record 28 of Set 10 | cartaya
# Processing Record 29 of Set 10 | vestmanna
# Processing Record 30 of Set 10 | miami
# Processing Record 31 of Set 10 | arrifes
# Processing Record 32 of Set 10 | saint combs
# 'coord'
# Processing Record 33 of Set 10 | santiago de cao
# Processing Record 34 of Set 10 | alta floresta
# Processing Record 35 of Set 10 | soe
# Processing Record 36 of Set 10 | dumas
# Processing Record 37 of Set 10 | tupanatinga
# Processing Record 38 of Set 10 | tambacounda
# Processing Record 39 of Set 10 | orumiyeh
# Processing Record 40 of Set 10 | gweru
# Processing Record 41 of Set 10 | kismayo
# Processing Record 42 of Set 10 | ambovombe
# Processing Record 43 of Set 10 | harnosand
# Processing Record 44 of Set 10 | staraya kulatka
# Processing Record 45 of Set 10 | koutsouras
# Processing Record 46 of Set 10 | la libertad
# Processing Record 47 of Set 10 | gamba
# Processing Record 48 of Set 10 | oranjemund
# Processing Record 49 of Set 10 | manyava
# Processing Record 50 of Set 10 | komsomolskiy
# Processing Record 1 of Set 11 | les cayes
# Processing Record 2 of Set 11 | coquimbo
# Processing Record 3 of Set 11 | kawalu
# Processing Record 4 of Set 11 | martapura
# Processing Record 5 of Set 11 | jugsalai
# Processing Record 6 of Set 11 | augusto correa
# Processing Record 7 of Set 11 | mikhaylovka
# Processing Record 8 of Set 11 | shelabolikha
# Processing Record 9 of Set 11 | port elgin
# Processing Record 10 of Set 11 | mapimi
# Processing Record 11 of Set 11 | rondonopolis
# Processing Record 12 of Set 11 | puquio
# Processing Record 13 of Set 11 | serenje
# Processing Record 14 of Set 11 | xichang
# Processing Record 15 of Set 11 | hearst
# Processing Record 16 of Set 11 | zharkent
# Processing Record 17 of Set 11 | naze
# Processing Record 18 of Set 11 | port-gentil
# Processing Record 19 of Set 11 | uyuni
# Processing Record 20 of Set 11 | voi
# Processing Record 21 of Set 11 | warmbad
# Processing Record 22 of Set 11 | diamantino
# Processing Record 23 of Set 11 | pekan
# Processing Record 24 of Set 11 | edeia
# Processing Record 25 of Set 11 | tucuman
# Processing Record 26 of Set 11 | tomelloso
# Processing Record 27 of Set 11 | tayga
# Processing Record 28 of Set 11 | birjand
# Processing Record 29 of Set 11 | ulladulla
# Processing Record 30 of Set 11 | darnah
# Processing Record 31 of Set 11 | snezhnogorsk
# Processing Record 32 of Set 11 | comodoro rivadavia
# Processing Record 33 of Set 11 | khani
# Processing Record 34 of Set 11 | rorvik
# Processing Record 35 of Set 11 | inhambane
# Processing Record 36 of Set 11 | copperas cove
# Processing Record 37 of Set 11 | olinda
# Processing Record 38 of Set 11 | grand gaube
# Processing Record 39 of Set 11 | portsmouth
# Processing Record 40 of Set 11 | mangrol
# Processing Record 41 of Set 11 | lolua
# 'coord'
# Processing Record 42 of Set 11 | carutapera
# Processing Record 43 of Set 11 | pacific grove
# Processing Record 44 of Set 11 | metro
# Processing Record 45 of Set 11 | oppdal
# Processing Record 46 of Set 11 | kamina
# Processing Record 47 of Set 11 | holme
# Processing Record 48 of Set 11 | puerto escondido
# Processing Record 49 of Set 11 | tel aviv-yafo
# Processing Record 50 of Set 11 | saint-augustin
# Processing Record 1 of Set 12 | acarau
# Processing Record 2 of Set 12 | inuvik
# Processing Record 3 of Set 12 | kidal
# Processing Record 4 of Set 12 | saint-pierre
# Processing Record 5 of Set 12 | bambous virieux
# Processing Record 6 of Set 12 | talara
# Processing Record 7 of Set 12 | tuy hoa
# Processing Record 8 of Set 12 | tyukhtet
# Processing Record 9 of Set 12 | nyurba
# Processing Record 10 of Set 12 | naftah
# 'coord'
# Processing Record 11 of Set 12 | muravlenko
# Processing Record 12 of Set 12 | atar
# Processing Record 13 of Set 12 | roebourne
# Processing Record 14 of Set 12 | kumluca
# Processing Record 15 of Set 12 | port pirie
# Processing Record 16 of Set 12 | bauchi
# Processing Record 17 of Set 12 | tabory
# Processing Record 18 of Set 12 | el alto
# Processing Record 19 of Set 12 | quatre cocos
# Processing Record 20 of Set 12 | moose factory
# Processing Record 21 of Set 12 | porto belo
# Processing Record 22 of Set 12 | rundu
# Processing Record 23 of Set 12 | luwuk
# Processing Record 24 of Set 12 | tyubuk
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | polson
# Processing Record 27 of Set 12 | maracas
# Processing Record 28 of Set 12 | coihaique
# Processing Record 29 of Set 12 | ohafia
# Processing Record 30 of Set 12 | kamenka
# Processing Record 31 of Set 12 | skjervoy
# Processing Record 32 of Set 12 | matay
# Processing Record 33 of Set 12 | abay
# Processing Record 34 of Set 12 | bargal
# 'coord'
# Processing Record 35 of Set 12 | kisszallas
# Processing Record 36 of Set 12 | inhambupe
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | sao filipe
# Processing Record 39 of Set 12 | thongwa
# Processing Record 40 of Set 12 | baruun-urt
# Processing Record 41 of Set 12 | robertsport
# Processing Record 42 of Set 12 | san roque
# Processing Record 43 of Set 12 | igarka
# Processing Record 44 of Set 12 | kitui
# Processing Record 45 of Set 12 | cayenne
# Processing Record 46 of Set 12 | tawnat
# 'coord'
# Processing Record 47 of Set 12 | moron
# Processing Record 48 of Set 12 | kelamangalam
# Processing Record 49 of Set 12 | tir pol
# 'coord'
# Processing Record 50 of Set 12 | pyay
# Processing Record 1 of Set 13 | mizdah
# Processing Record 2 of Set 13 | dalnerechensk
# Processing Record 3 of Set 13 | taoudenni
# Processing Record 4 of Set 13 | charters towers
# Processing Record 5 of Set 13 | yaan
# Processing Record 6 of Set 13 | ndele
# Processing Record 7 of Set 13 | minudasht
# Processing Record 8 of Set 13 | natal
# Processing Record 9 of Set 13 | buqayq
# 'coord'
# Processing Record 10 of Set 13 | buford
# Processing Record 11 of Set 13 | portland
# Processing Record 12 of Set 13 | mackenzie
# Processing Record 13 of Set 13 | pimentel
# Processing Record 14 of Set 13 | saint stephen
# Processing Record 15 of Set 13 | anori
# Processing Record 16 of Set 13 | codrington
# Processing Record 17 of Set 13 | mandalgovi
# Processing Record 18 of Set 13 | akhmim
# Processing Record 19 of Set 13 | opuwo
# Processing Record 20 of Set 13 | sinnamary
# Processing Record 21 of Set 13 | bunog
# Processing Record 22 of Set 13 | hohhot
# Processing Record 23 of Set 13 | sainte-suzanne
# Processing Record 24 of Set 13 | ajaccio
# Processing Record 25 of Set 13 | tayoltita
# Processing Record 26 of Set 13 | chissamba
# Processing Record 27 of Set 13 | port hawkesbury
# Processing Record 28 of Set 13 | bridgetown
# Processing Record 29 of Set 13 | bakchar
# Processing Record 30 of Set 13 | udarnyy
# Processing Record 31 of Set 13 | kuusamo
# Processing Record 32 of Set 13 | virginia beach
# Processing Record 33 of Set 13 | plettenberg bay
# Processing Record 34 of Set 13 | svetlaya
# Processing Record 35 of Set 13 | taltal
# Processing Record 36 of Set 13 | ilave
# Processing Record 37 of Set 13 | gazojak
# Processing Record 38 of Set 13 | satitoa
# 'coord'
# Processing Record 39 of Set 13 | zeya
# Processing Record 40 of Set 13 | digha
# Processing Record 41 of Set 13 | turtas
# Processing Record 42 of Set 13 | pakxan
# Processing Record 43 of Set 13 | shimoda
# Processing Record 44 of Set 13 | todos santos
# Processing Record 45 of Set 13 | meulaboh
# Processing Record 46 of Set 13 | mount isa
# Processing Record 47 of Set 13 | loukhi
# Processing Record 48 of Set 13 | beloha
# Processing Record 49 of Set 13 | mersing
# Processing Record 50 of Set 13 | linfen
# Processing Record 1 of Set 14 | mildura
# Processing Record 2 of Set 14 | tabas
# Processing Record 3 of Set 14 | venta
# Processing Record 4 of Set 14 | odienne
# Processing Record 5 of Set 14 | krasnoyarsk-45
# 'coord'
# Processing Record 6 of Set 14 | dosso
# Processing Record 7 of Set 14 | selma
# Processing Record 8 of Set 14 | bathsheba
# Processing Record 9 of Set 14 | lishui
# Processing Record 10 of Set 14 | talnakh
# Processing Record 11 of Set 14 | labuhan
# Processing Record 12 of Set 14 | syracuse
# Processing Record 13 of Set 14 | umm kaddadah
# Processing Record 14 of Set 14 | maragogi
# Processing Record 15 of Set 14 | nemuro
# Processing Record 16 of Set 14 | salekhard
# Processing Record 17 of Set 14 | eyl
# Processing Record 18 of Set 14 | kihei
# Processing Record 19 of Set 14 | grants pass
# Processing Record 20 of Set 14 | ojinaga
# Processing Record 21 of Set 14 | le tampon
# Processing Record 22 of Set 14 | udachnyy
# Processing Record 23 of Set 14 | bilibino
# Processing Record 24 of Set 14 | agirish
# Processing Record 25 of Set 14 | juneau
# Processing Record 26 of Set 14 | san ciro de acosta
# Processing Record 27 of Set 14 | benghazi
# Processing Record 28 of Set 14 | san quintin
# Processing Record 29 of Set 14 | penzance
# Processing Record 30 of Set 14 | tabukiniberu
# 'coord'
# Processing Record 31 of Set 14 | boca raton
# Processing Record 32 of Set 14 | alotau
# 'coord'
# Processing Record 33 of Set 14 | kandrian
# Processing Record 34 of Set 14 | saldanha
# Processing Record 35 of Set 14 | ust-koksa
# Processing Record 36 of Set 14 | palana
# Processing Record 37 of Set 14 | haibowan
# 'coord'
# Processing Record 38 of Set 14 | morehead
# Processing Record 39 of Set 14 | daru
# Processing Record 40 of Set 14 | kostomuksha
# Processing Record 41 of Set 14 | baykit
# Processing Record 42 of Set 14 | dapaong
# Processing Record 43 of Set 14 | mananjary
# Processing Record 44 of Set 14 | kachug
# Processing Record 45 of Set 14 | jiddah
# 'coord'
# Processing Record 46 of Set 14 | port macquarie
# Processing Record 47 of Set 14 | lahaina
# Processing Record 48 of Set 14 | boyolangu
# Processing Record 49 of Set 14 | sandnessjoen
# Processing Record 50 of Set 14 | guangyuan
# Processing Record 1 of Set 15 | liliani
# Processing Record 2 of Set 15 | padang
# Processing Record 3 of Set 15 | ajdabiya
# Processing Record 4 of Set 15 | moosomin
# Processing Record 5 of Set 15 | truro
# Processing Record 6 of Set 15 | careiro da varzea
# Processing Record 7 of Set 15 | zyryanka
# Processing Record 8 of Set 15 | camocim
# Processing Record 9 of Set 15 | teguise
# Processing Record 10 of Set 15 | oistins
# Processing Record 11 of Set 15 | dutse
# Processing Record 12 of Set 15 | mareeba
# Processing Record 13 of Set 15 | barra patuca
# Processing Record 14 of Set 15 | oliveira dos brejinhos
# Processing Record 15 of Set 15 | formoso do araguaia
# 'coord'
# Processing Record 16 of Set 15 | callaway
# Processing Record 17 of Set 15 | sukhobezvodnoye
# Processing Record 18 of Set 15 | mantua
# Processing Record 19 of Set 15 | boa viagem
# Processing Record 20 of Set 15 | biltine
# Processing Record 21 of Set 15 | jiuquan
# Processing Record 22 of Set 15 | northam
# Processing Record 23 of Set 15 | ixtapa
# Processing Record 24 of Set 15 | medernach
# Processing Record 25 of Set 15 | pallasovka
# Processing Record 26 of Set 15 | kuching
# Processing Record 27 of Set 15 | tuatapere
# Processing Record 28 of Set 15 | hegang
# Processing Record 29 of Set 15 | arvika
# Processing Record 30 of Set 15 | stornoway
# Processing Record 31 of Set 15 | ukiah
# Processing Record 32 of Set 15 | cozumel
# Processing Record 33 of Set 15 | bethanien
# Processing Record 34 of Set 15 | gumdag
# Processing Record 35 of Set 15 | belmonte
# Processing Record 36 of Set 15 | leh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 679

# %%
# Add data to the new datafram.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Hobart -42.88  147.33     43.00        80          20        8.05
# 1       Dalbandin  28.89   64.41     57.92        28           0        2.57
# 2         Qaanaaq  77.48  -69.36    -12.95        71           0        7.56
# 3           Kapaa  22.08 -159.32     80.60        83          40       10.29
# 4          Bethel  41.37  -73.41     73.40        35           1        4.70
# 5      Harrismith -28.27   29.13     62.74        48           0        5.48
# 6       Busselton -33.65  115.33     55.00        66          47        2.75
# 7        Bengkulu  -3.80  102.27     76.14        86         100        4.12
# 8  Saint-Philippe -21.36   55.77     73.40        78           0       11.41
# 9         Madimba -10.40   40.33     78.80        83          20        7.61
#
#   Country Current Description
# 0      AU          few clouds
# 1      PK           clear sky
# 2      GL           clear sky
# 3      US       moderate rain
# 4      US           clear sky
# 5      ZA           clear sky
# 6      AU    scattered clouds
# 7      ID     overcast clouds
# 8      RE           clear sky
# 9      TZ          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart      AU -42.88  147.33     43.00        80          20
# 1       Dalbandin      PK  28.89   64.41     57.92        28           0
# 2         Qaanaaq      GL  77.48  -69.36    -12.95        71           0
# 3           Kapaa      US  22.08 -159.32     80.60        83          40
# 4          Bethel      US  41.37  -73.41     73.40        35           1
# 5      Harrismith      ZA -28.27   29.13     62.74        48           0
# 6       Busselton      AU -33.65  115.33     55.00        66          47
# 7        Bengkulu      ID  -3.80  102.27     76.14        86         100
# 8  Saint-Philippe      RE -21.36   55.77     73.40        78           0
# 9         Madimba      TZ -10.40   40.33     78.80        83          20
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        2.57           clear sky
# 2        7.56           clear sky
# 3       10.29       moderate rain
# 4        4.70           clear sky
# 5        5.48           clear sky
# 6        2.75    scattered clouds
# 7        4.12     overcast clouds
# 8       11.41           clear sky
# 9        7.61          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
